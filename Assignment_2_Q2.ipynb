# %% [markdown]
# <a href="https://colab.research.google.com/github/iamsankar999/IPL_data_power_BI/blob/main/Assignment_2_Q2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
data = np.array([55.3, 55.3, 55.3, 55.9, 55.9, 55.9, 55.9, 56.1, 56.1, 56.1, 56.1, 56.1, 56.1, 56.8, 56.8, 57.0, 57.0, 57.0, 57.8, 57.8, 57.8, 57.9, 57.9, 57.9, 58.8, 58.8, 58.8, 59.8, 59.8, 59.8, 62.2, 62.2, 63.8, 63.8, 63.8, 63.9, 63.9, 63.9, 64.7, 64.7, 64.7, 65.1, 65.1, 65.1, 65.3, 65.3, 65.3, 65.3, 67.4, 67.4, 67.4, 67.4, 68.7, 68.7, 68.7, 68.7, 69.0, 70.4, 70.4, 71.2, 71.2, 71.2, 73.0, 73.0, 73.1, 73.1, 74.6, 74.6, 74.6, 74.6, 79.3, 79.3, 79.3, 79.3, 83.0, 83.0, 83.0])

# %%
# Measures of Central Tendency
mean = np.mean(data)
median = np.median(data)

#Printing the data
print("Measures of Central Tendency:")
print("Mean:", mean)
print("Median:", median)
# Out:
# Measures of Central Tendency:
# Mean: 64.887012987013
# Median: 64.7

# %%
# Measures of Dispersion
variance = np.var(data)
std_deviation = np.std(data)
mad_mean = np.mean(np.abs(data - mean))
mad_median = np.mean(np.abs(data - median))
range_val = np.ptp(data)
rms= np.sqrt((np.sum(np.square(data)))/len(data))


#Printing the data.
print("\nMeasures of Dispersion:")
print("Variance:", variance)
print("Standard Deviation:", std_deviation)
print("Mean Absolute Deviation (from Mean):", mad_mean)
print("Mean Absolute Deviation (from Median):", mad_median)
print("Range:", range_val)
print('RMS value:', rms)
# Out:
# Measures of Dispersion:
# Variance: 60.091000168662504
# Standard Deviation: 7.751838502488458
# Mean Absolute Deviation (from Mean): 6.367987856299545
# Mean Absolute Deviation (from Median): 6.355844155844157
# Range: 27.700000000000003
# RMS value: 65.34841585337364

# %% [markdown]
# Plotting the data

# %%
#Boxplot
sns.boxplot(data)
# Out:
# <Axes: >

# %% [markdown]
# Median
#
# The median (middle quartile) marks the mid-point of the data and is shown by the line that divides the box into two parts. Half the scores are greater than or equal to this value and half are less.
#
# Inter-quartile range
#
# The middle “box” represents the middle 50% of scores for the group. The range of scores from lower to upper quartile is referred to as the inter-quartile range. The middle 50% of scores fall within the inter-quartile range.
#
# Upper quartile
#
# Seventy-five percent of the scores fall below the upper quartile.
#
# Lower quartile
#
# Twenty-five percent of scores fall below the lower quartile.
#
# Whiskers
#
# The upper and lower whiskers represent scores outside the middle 50%. Whiskers often (but not always) stretch over a wider range of scores than the middle quartile groups.

# %%
#Histogram plot
sns.histplot(data, kde=True, color='blue')
# Out:
# <Axes: ylabel='Count'>

# %%
#Violin plot
sns.violinplot(x=data, color='purple', inner='quartiles')
# Out:
# <Axes: >
